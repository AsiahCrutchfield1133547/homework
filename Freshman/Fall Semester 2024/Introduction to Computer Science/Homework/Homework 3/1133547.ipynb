# %%
#Asiah Crutchfield | 1133547 | 16 Nov 2024
import random

#Problem 1: A while loop to print numbers 1-10

def oneToTen():
  count = 1
  while count <= 10:
    print("Number: ", count)
    count += 1

#Problem 2: A program to determine whether a number is even or odd
def evenOrOdd():
  number = random.randint(1, 1000)
  print(f"This is your number:",number)
  if (number % 2 != 0):
    print("This number is odd.")
  else:
    print("This number is even.")

#Problem 3: A program to find the largest number in a list
def largestNum():
  list = [random.randint(1, 100) for i in range(random.randint(3, 10))]
  largest = list[0]
  print(f"Your list:", list)
  for i in list:
    if i > largest:
      largest = i
  print(f"This is the largest number:", largest)

#Problem 4: A program to see if the number "25" exists in a list
def foundOrNot():
  list = [random.randint(1, 100) for i in range(random.randint(3, 10))]
  found = False

  for i in list:
    if i == 25:
      print("Found it!")
      found = True
      break
  if not found:
    print("Not found.")
    print(list)

#Problem 5: A program that checks whether or not the weather is pleasant based on a certain temperature
def pleasantWeather():
  temperature = random.randint(25, 60)
  if (temperature > 30):
    print("It's hot outside!")
    print(f"Temp:", temperature, "C")
  else:
    print("It's pleasant outside.")
    print(f"Temp:", temperature, "C")

oneToTen()
print("")
evenOrOdd()
print("")
largestNum()
print("")
foundOrNot()
print("")
pleasantWeather()
# Out:
# Number:  1
# Number:  2
# Number:  3
# Number:  4
# Number:  5
# Number:  6
# Number:  7
# Number:  8
# Number:  9
# Number:  10
#
# This is your number: 448
# This number is even.
#
# Your list: [26, 26, 44, 6, 49, 94, 51, 54, 12, 2]
# This is the largest number: 94
#
# Not found.
# [88, 7, 2, 70, 5, 100, 16, 70]
#
# It's pleasant outside.
# Temp: 29 C
